# %% [markdown]
# ### Àlex Correa Orri 1564967
# ### Júlia Pumares Benaiges 1566252

# %% [markdown]
# #### Dataset: https://www.kaggle.com/iabhishekofficial/mobile-price-classification

# %%
reset()
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])? y
# Don't know how to reset  (), please run `%reset?` for details

# %% [markdown]
# ### MÒDULS I LLIBRERIES

# %%
from sklearn.datasets import make_regression
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import scipy.stats
import os
import seaborn as sns
from scipy.stats import shapiro, spearmanr
import math
import sklearn
from sklearn import metrics
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
import ipympl
from sklearn.linear_model import LogisticRegression
from sklearn import svm, datasets
from sklearn.model_selection import train_test_split
from sklearn.linear_model import Perceptron
from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import cross_val_score
from sklearn.tree import DecisionTreeRegressor
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import BaggingClassifier
from sklearn import metrics
from sklearn.ensemble import AdaBoostClassifier
from sklearn.model_selection import LeaveOneOut
from sklearn.metrics import classification_report
from sklearn.metrics import f1_score, precision_recall_curve, average_precision_score, roc_curve, auc
# %matplotlib widget
import warnings
warnings.filterwarnings('ignore')
#warnings.filterwarnings(action='once')

# %% [markdown]
# ### DIRECTORI DE TREBALL

# %%
os.getcwd()
#path = 'C:/Users/alexc/OneDrive/Escritorio/UNI/3er/Aprenentatge Computacional/pràctiques/PRÀCTICA 2/Practica2-Classificacio'
path = 'C:/Users/julia/Downloads'
os.chdir(path)
os.getcwd()
# Visualitzarem només 3 decimals per mostra
pd.set_option('display.float_format', lambda x: '%.3f' % x)

# %% [markdown]
# ### LECTURA DE DADES

# %%
# Funcio per a llegir dades en format csv
def load_dataset(path):
    dataset = pd.read_csv(path, header=0, delimiter=',')
    return dataset

# Carreguem dataset d'exemple
dataset = load_dataset('train.csv')

dataset_test = load_dataset('test.csv')

# %% [markdown]
# ### 1- EDA

# %%
dataset
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0               842     0        2.200         0   1       0           7
# 1              1021     1        0.500         1   0       1          53
# 2               563     1        0.500         1   2       1          41
# 3               615     1        2.500         0   0       0          10
# 4              1821     1        1.200         0  13       1          44
# 5              1859     0        0.500         1   3       0          22
# 6              1821     0        1.700         0   4       1          10
# 7              1954     0        0.500         1   0       0          24
# 8              1445     1        0.500         0   0       0          53
# 9               509     1        0.600         1   2       1           9
# 10              769     1        2.900         1   0       0           9
# 11             1520     1        2.200         0   5       1          33
# 12             1815     0        2.800         0   2       0          33
# 13              803     1        2.100         0   7       0          17
# 14             1866     0        0.500         0  13       1          52
# 15              775     0        1.000         0   3       0          46
# 16              838     0        0.500         0   1       1          13
# 17              595     0        0.900         1   7       1          23
# 18             1131     1        0.500         1  11       0          49
# 19              682     1        0.500         0   4       0          19
# 20              772     0        1.100         1  12       0          39
# 21             1709     1        2.100         0   1       0          13
# 22             1949     0        2.600         1   4       0          47
# 23             1602     1        2.800         1   4       1          38
# 24              503     0        1.200         1   5       1           8
# 25              961     1        1.400         1   0       1          57
# 26              519     1        1.600         1   7       1          51
# 27              956     0        0.500         0   1       1          41
# 28             1453     0        1.600         1  12       1          52
# 29              851     0        0.500         0   3       0          21
# ...             ...   ...          ...       ...  ..     ...         ...
# 1970           1913     1        1.800         0   0       0          29
# 1971            538     0        1.100         1   0       1          25
# 1972           1191     0        0.800         0   6       1          46
# 1973            816     0        3.000         1   2       0           9
# 1974            915     1        0.500         1   9       1          33
# 1975           1157     1        0.800         0   7       0          27
# 1976           1201     1        0.500         0   2       0          10
# 1977           1379     0        1.100         1   1       1          18
# 1978           1483     1        2.200         0   3       1          53
# 1979           1614     0        1.200         0   1       1           9
# 1980            930     1        1.000         1   4       1           4
# 1981           1454     0        2.600         0   8       0           6
# 1982           1784     0        1.600         0   4       0          41
# 1983           1262     0        1.800         1  12       0          34
# 1984            797     0        2.200         1   0       0          37
# 1985           1829     1        2.100         0   8       0          59
# 1986           1139     1        0.900         1   6       1          58
# 1987            618     1        1.000         0   9       1          13
# 1988           1547     1        2.900         0   2       0          57
# 1989            586     0        2.800         0   2       0          15
# 1990           1617     1        2.400         0   8       1          36
# 1991           1882     0        2.000         0  11       1          44
# 1992            674     1        2.900         1   1       0          21
# 1993           1467     1        0.500         0   0       0          18
# 1994            858     0        2.200         0   1       0          50
# 1995            794     1        0.500         1   0       1           2
# 1996           1965     1        2.600         1   0       0          39
# 1997           1911     0        0.900         1   1       1          36
# 1998           1512     0        0.900         0   4       1          46
# 1999            510     1        2.000         1   5       1          45
#
#       m_dep  mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  \
# 0     0.600        188        2  ...         20       756  2549     9     7
# 1     0.700        136        3  ...        905      1988  2631    17     3
# 2     0.900        145        5  ...       1263      1716  2603    11     2
# 3     0.800        131        6  ...       1216      1786  2769    16     8
# 4     0.600        141        2  ...       1208      1212  1411     8     2
# 5     0.700        164        1  ...       1004      1654  1067    17     1
# 6     0.800        139        8  ...        381      1018  3220    13     8
# 7     0.800        187        4  ...        512      1149   700    16     3
# 8     0.700        174        7  ...        386       836  1099    17     1
# 9     0.100         93        5  ...       1137      1224   513    19    10
# 10    0.100        182        5  ...        248       874  3946     5     2
# 11    0.500        177        8  ...        151      1005  3826    14     9
# 12    0.600        159        4  ...        607       748  1482    18     0
# 13    1.000        198        4  ...        344      1440  2680     7     1
# 14    0.700        185        1  ...        356       563   373    14     9
# 15    0.700        159        2  ...        862      1864   568    17    15
# 16    0.100        196        8  ...        984      1850  3554    10     9
# 17    0.100        121        3  ...        441       810  3752    10     2
# 18    0.600        101        5  ...        658       878  1835    19    13
# 19    1.000        121        4  ...        902      1064  2337    11     1
# 20    0.800         81        7  ...       1314      1854  2819    17    15
# 21    1.000        156        2  ...        974      1385  3283    17     1
# 22    0.300        199        4  ...        407       822  1433    11     5
# 23    0.700        114        3  ...        466       788  1037     8     7
# 24    0.400        111        3  ...        201      1245  2583    11     0
# 25    0.600        114        8  ...        291      1434  2782    18     9
# 26    0.300        132        4  ...        550       645  3763    16     1
# 27    1.000        143        7  ...        511      1075  3286    17     8
# 28    0.300         96        2  ...        187      1311  2373    10     1
# 29    0.400        200        5  ...       1171      1263   478    12     7
# ...     ...        ...      ...  ...        ...       ...   ...   ...   ...
# 1970  0.600        111        5  ...        675       742  2023    17    13
# 1971  0.300        163        7  ...        455       537  2215     9     3
# 1972  0.800         89        6  ...         42       807   824    19    18
# 1973  0.100        117        1  ...       1196      1651  3851    10     3
# 1974  0.300        199        2  ...        503       986  2156     7     3
# 1975  0.100         88        8  ...       1694      1798  2885     8     4
# 1976  1.000         99        7  ...        306       558   495    15     6
# 1977  0.200        129        2  ...        838       885  2358    10     5
# 1978  0.700        169        5  ...        291       651  1744     6     3
# 1979  0.100        161        3  ...        173      1219  1832    15     8
# 1980  0.900        144        8  ...       1017      1289  2016    13    10
# 1981  0.400        199        3  ...        698      1018  1300    10     0
# 1982  0.400        164        6  ...        610      1437  2313    14     1
# 1983  0.100        149        5  ...        223       737  3248    13     3
# 1984  0.900        144        7  ...        206      1167  2216     9     5
# 1985  0.100         91        5  ...       1457      1919  3142    16     6
# 1986  0.500        161        2  ...        742       999  1850     9     4
# 1987  0.100         80        4  ...        591       724  1424    15    12
# 1988  0.400        114        1  ...        347       957  1620     9     2
# 1989  0.200         83        3  ...        241       854  2592    12     8
# 1990  0.800         85        1  ...        743      1426   296     5     3
# 1991  0.800        113        8  ...          4       743  3579    19     8
# 1992  0.200        198        3  ...        576      1809  1180     6     3
# 1993  0.600        122        5  ...        888      1099  3962    15    11
# 1994  0.100         84        1  ...        528      1416  3978    17    16
# 1995  0.800        106        6  ...       1222      1890   668    13     4
# 1996  0.200        187        4  ...        915      1965  2032    11    10
# 1997  0.700        108        8  ...        868      1632  3057     9     1
# 1998  0.100        145        5  ...        336       670   869    18    10
# 1999  0.900        168        6  ...        483       754  3919    19     4
#
#       talk_time  three_g  touch_screen  wifi  price_range
# 0            19        0             0     1            1
# 1             7        1             1     0            2
# 2             9        1             1     0            2
# 3            11        1             0     0            2
# 4            15        1             1     0            1
# 5            10        1             0     0            1
# 6            18        1             0     1            3
# 7             5        1             1     1            0
# 8            20        1             0     0            0
# 9            12        1             0     0            0
# 10            7        0             0     0            3
# 11           13        1             1     1            3
# 12            2        1             0     0            1
# 13            4        1             0     1            2
# 14            3        1             0     1            0
# 15           11        1             1     1            0
# 16           19        1             0     1            3
# 17           18        1             1     0            3
# 18           16        1             1     0            1
# 19           18        0             1     1            1
# 20            3        1             1     0            3
# 21           15        1             0     0            3
# 22           20        0             0     1            1
# 23           20        1             0     0            0
# 24           12        1             0     0            1
# 25            7        1             1     1            2
# 26            4        1             0     1            3
# 27           12        1             1     0            3
# 28           10        1             1     1            2
# 29           10        1             0     1            0
# ...         ...      ...           ...   ...          ...
# 1970          8        1             1     0            2
# 1971         17        1             1     1            1
# 1972          7        1             0     0            0
# 1973         14        1             0     1            3
# 1974         13        1             1     0            1
# 1975          2        1             0     1            3
# 1976         14        1             1     1            0
# 1977         15        1             1     0            2
# 1978         10        1             0     0            1
# 1979         11        1             0     0            1
# 1980         16        1             1     1            1
# 1981          2        0             0     1            1
# 1982         11        0             1     0            2
# 1983          4        0             1     1            2
# 1984          6        1             0     0            1
# 1985          5        1             1     1            3
# 1986          8        1             0     0            1
# 1987          7        1             1     0            0
# 1988         19        0             1     1            1
# 1989          3        0             0     0            1
# 1990          7        1             0     0            0
# 1991         20        1             1     0            3
# 1992          4        1             1     1            0
# 1993          5        1             1     1            3
# 1994          3        1             1     0            3
# 1995         19        1             1     0            0
# 1996         16        1             1     1            2
# 1997          5        1             1     0            3
# 1998         19        1             1     1            0
# 1999          2        1             1     1            3
#
# [2000 rows x 21 columns]

# %% [markdown]
# #### Atributs

# %%
dataset.columns
# Out:
# Index(['battery_power', 'blue', 'clock_speed', 'dual_sim', 'fc', 'four_g',
#        'int_memory', 'm_dep', 'mobile_wt', 'n_cores', 'pc', 'px_height',
#        'px_width', 'ram', 'sc_h', 'sc_w', 'talk_time', 'three_g',
#        'touch_screen', 'wifi', 'price_range'],
#       dtype='object')

# %% [markdown]
# #### Determinem com l'atribut objectiu el price_range (4 rangs de preu)

# %%
data = dataset.values
l = len(dataset.columns)
X = data[:, :l]
y = data[:, l-1]

# %% [markdown]
# #### Correlacions amb l'atribut a predir (price_range)

# %%
plt.figure()
ax = sns.heatmap(dataset.corr(), annot=False, linewidths=.5)

# %%
dataset.corr()['price_range']
# Out:
# battery_power    0.201
# blue             0.021
# clock_speed     -0.007
# dual_sim         0.017
# fc               0.022
# four_g           0.015
# int_memory       0.044
# m_dep            0.001
# mobile_wt       -0.030
# n_cores          0.004
# pc               0.034
# px_height        0.149
# px_width         0.166
# ram              0.917
# sc_h             0.023
# sc_w             0.039
# talk_time        0.022
# three_g          0.024
# touch_screen    -0.030
# wifi             0.019
# price_range      1.000
# Name: price_range, dtype: float64

# %% [markdown]
# #### Dades amb distribució normal

# %%
c = 0
for col in dataset.columns:
    stat, p = shapiro(X[:,c])
    if p > 0.05:
        print(c, p)
        print(dataset.columns[c])
    c += 1
#no tenim dades amb distribució normal

# %%
#Histograma dels atributs
sns.distplot(X[:,13])

# %% [markdown]
# #### Scatter plot dels atributs més correlacionats (ram i battery_power) amb price_range

# %%
n_classes = 4
    
plt.figure()
plt.xlabel("ram")
plt.ylabel("price_range")
plt.scatter(X[:,13], y, c=y, cmap=plt.cm.coolwarm, edgecolors='k')

# %%
plt.figure()
plt.xlabel("battery_power")
plt.ylabel("price_range")
plt.scatter(X[:,0], y, c=y, cmap=plt.cm.coolwarm, edgecolors='k')

# %% [markdown]
# #### Dades binàries

# %%
bool_cols = [col for col in dataset if np.isin(dataset[col].dropna().unique(), [0, 1]).all()]
bool_cols
# Out:
# ['blue', 'dual_sim', 'four_g', 'three_g', 'touch_screen', 'wifi']

# %% [markdown]
# #### Les resta de dades són numèriques (enteres o decimals), no tenim categòriques

# %% [markdown]
# ### 2- Preprocessing

# %% [markdown]
# #### No tenim valors NaN

# %%
print(dataset.isnull().values.any())
print(dataset_test.isnull().values.any())
# Out:
# False
# False

# %% [markdown]
# #### Provem si val la pena tenir amplada i alçada o podem utilitzar la mida de la diagonal. Creem atribut nou, px_diag

# %%
dataset['px_diag'] = (dataset['px_height']**2+dataset['px_width']**2)**(1/2)
dataset = dataset.drop(['px_width','px_height'],axis=1)
dataset_test['px_diag'] = (dataset_test['px_height']**2+dataset_test['px_width']**2)**(1/2)
dataset_test = dataset_test.drop(['px_width','px_height'],axis=1)
data = dataset.values
l = len(dataset.columns)
X = data[:, :l-1] 
y = data[:, dataset.columns.get_loc('price_range')]

# %%
dataset.corr()['px_diag']['price_range']
# Out:
# 0.1803849801917853

# %% [markdown]
# #### Creem dataset1 amb els atributs més correlacionats

# %%
cols_corr=['battery_power','ram','px_diag','price_range']

# %%
dataset1 = dataset[cols_corr]
data1 = dataset1.values
l1 = len(dataset1.columns)
X1 = data1[:, :l1-1]

# %%
plt.figure()
ax = sns.heatmap(dataset1.corr(), annot=True, linewidths=.5)

# %% [markdown]
# #### Normalitzar

# %%
def standarize(x_train):
    mean = x_train.mean(0)
    std = x_train.std(0)
    x_t = x_train - mean[None, :]
    x_t /= std[None, :]
    return x_t

# %%
Xn = standarize(X)
X1n = standarize(X1)

# %% [markdown]
# #### Pairplot

# %%
sns.pairplot(dataset1, hue='price_range')

# %% [markdown]
# ### 3- Model Selection

# %%
def models(X, y):
    particions = [0.5, 0.7, 0.8]
    scores = {}
    for part in particions:
        print("PART: "+str(part)+" %")
        x_t, x_v, y_t, y_v = train_test_split(X, y, train_size=part, stratify=y)

        #Regresor logístic
        logireg = LogisticRegression(C=2.0, fit_intercept=True, penalty='l2', tol=0.001)
        logireg.fit(x_t, y_t)
        scores["Logístic           "] = round(logireg.score(x_v, y_v),2)
        
        #SVM
        svc = svm.SVC(C=10.0, kernel='rbf', gamma=0.9, probability=True)
        svc.fit(x_t, y_t)
        scores["SVM                "] = round(svc.score(x_v, y_v),2)
        
        #DecisionTree
        clft = DecisionTreeClassifier(random_state=0, max_depth=2)
        clft.fit(x_t, y_t)
        scores["Decision Tree      "] = round(clft.score(x_v, y_v),2)
        
        #perceptron
        clf = Perceptron(tol=1e-3, random_state=0)
        clf.fit(x_t, y_t)
        scores["Perceptron         "] = round(clf.score(x_v, y_v),2)
        
        #KNeighbors
        neigh = KNeighborsClassifier(n_neighbors=3)
        neigh.fit(x_t, y_t) 
        scores["KNeighbors         "] = round(neigh.score(x_v, y_v),2)
       
        #bagging
        bagging = BaggingClassifier(KNeighborsClassifier(n_neighbors=3), max_samples=0.5, max_features=0.5)
        bagging.fit(x_t, y_t)
        scores["Bagging KNeighbors "] = round(bagging.score(x_v, y_v),2)
        
        #adaboost
        adaB = AdaBoostClassifier(n_estimators=100)
        adaB.fit(x_t, y_t)
        scores["AdaBoost           "] = round(adaB.score(x_v, y_v),2)
        
        sort_scores = sorted(scores.items(), key=lambda x: x[1], reverse=True)
        for i in sort_scores:
            print("Correct classification ", i[0], i[1])
        print("-------------------------------------------------------------------")

# %% [markdown]
# #### Amb tots els atributs

# %%
models(X,y)
# Out:
# PART: 0.5 %
# Correct classification  Decision Tree       1.0
# Correct classification  KNeighbors          0.78
# Correct classification  Bagging KNeighbors  0.78
# Correct classification  AdaBoost            0.75
# Correct classification  Logístic            0.74
# Correct classification  Perceptron          0.5
# Correct classification  SVM                 0.27
# -------------------------------------------------------------------
# PART: 0.7 %
# Correct classification  Decision Tree       1.0
# Correct classification  KNeighbors          0.79
# Correct classification  Bagging KNeighbors  0.79
# Correct classification  AdaBoost            0.75
# Correct classification  Logístic            0.7
# Correct classification  Perceptron          0.36
# Correct classification  SVM                 0.27
# -------------------------------------------------------------------
# PART: 0.8 %
# Correct classification  Decision Tree       1.0
# Correct classification  Bagging KNeighbors  0.8
# Correct classification  KNeighbors          0.78
# Correct classification  Logístic            0.75
# Correct classification  AdaBoost            0.75
# Correct classification  Perceptron          0.42
# Correct classification  SVM                 0.26
# -------------------------------------------------------------------

# %% [markdown]
# #### Amb els atributs més correlacionats

# %%
models(X1, y)
# Out:
# PART: 0.5 %
# Correct classification  KNeighbors          0.9
# Correct classification  AdaBoost            0.78
# Correct classification  Decision Tree       0.75
# Correct classification  Logístic            0.6
# Correct classification  Perceptron          0.41
# Correct classification  Bagging KNeighbors  0.36
# Correct classification  SVM                 0.26
# -------------------------------------------------------------------
# PART: 0.7 %
# Correct classification  KNeighbors          0.91
# Correct classification  AdaBoost            0.78
# Correct classification  Decision Tree       0.74
# Correct classification  Bagging KNeighbors  0.52
# Correct classification  Logístic            0.48
# Correct classification  Perceptron          0.46
# Correct classification  SVM                 0.26
# -------------------------------------------------------------------
# PART: 0.8 %
# Correct classification  KNeighbors          0.9
# Correct classification  Decision Tree       0.74
# Correct classification  AdaBoost            0.71
# Correct classification  Bagging KNeighbors  0.67
# Correct classification  Logístic            0.48
# Correct classification  Perceptron          0.35
# Correct classification  SVM                 0.27
# -------------------------------------------------------------------

# %% [markdown]
# #### Amb dades normalitzades (tots els atributs)

# %%
models(Xn, y)
# Out:
# PART: 0.5 %
# Correct classification  Decision Tree       1.0
# Correct classification  Logístic            0.91
# Correct classification  Bagging KNeighbors  0.82
# Correct classification  AdaBoost            0.75
# Correct classification  Perceptron          0.7
# Correct classification  KNeighbors          0.6
# Correct classification  SVM                 0.42
# -------------------------------------------------------------------
# PART: 0.7 %
# Correct classification  Decision Tree       1.0
# Correct classification  Logístic            0.95
# Correct classification  Bagging KNeighbors  0.77
# Correct classification  AdaBoost            0.75
# Correct classification  Perceptron          0.71
# Correct classification  KNeighbors          0.62
# Correct classification  SVM                 0.42
# -------------------------------------------------------------------
# PART: 0.8 %
# Correct classification  Decision Tree       1.0
# Correct classification  Logístic            0.97
# Correct classification  Bagging KNeighbors  0.86
# Correct classification  AdaBoost            0.75
# Correct classification  Perceptron          0.65
# Correct classification  KNeighbors          0.57
# Correct classification  SVM                 0.45
# -------------------------------------------------------------------

# %% [markdown]
# #### Amb els atributs correlacionats i normalitzats

# %%
models(X1n, y)
# Out:
# PART: 0.5 %
# Correct classification  SVM                 0.93
# Correct classification  KNeighbors          0.9
# Correct classification  Logístic            0.83
# Correct classification  AdaBoost            0.81
# Correct classification  Perceptron          0.77
# Correct classification  Decision Tree       0.74
# Correct classification  Bagging KNeighbors  0.6
# -------------------------------------------------------------------
# PART: 0.7 %
# Correct classification  SVM                 0.92
# Correct classification  KNeighbors          0.92
# Correct classification  Logístic            0.85
# Correct classification  Perceptron          0.79
# Correct classification  AdaBoost            0.77
# Correct classification  Decision Tree       0.76
# Correct classification  Bagging KNeighbors  0.7
# -------------------------------------------------------------------
# PART: 0.8 %
# Correct classification  SVM                 0.93
# Correct classification  KNeighbors          0.9
# Correct classification  Logístic            0.84
# Correct classification  AdaBoost            0.79
# Correct classification  Decision Tree       0.74
# Correct classification  Perceptron          0.74
# Correct classification  Bagging KNeighbors  0.74
# -------------------------------------------------------------------

# %% [markdown]
# ### 4- Cross Validation

# %%
def cross_validation(X, regression, n_folds):
    scores = cross_val_score(regression, X1n, y, cv=n_folds)
    print ("Scores      :  ", scores)
    print ("Scores Mean :  ", scores.mean())
    print ("Scores std  :  ", scores.std())

# %%
folds = 5
print("\nSVM:")
svc = svm.SVC(C=100.0, kernel='rbf', gamma=0.9, probability=True)
cross_validation(X1n, svc, folds)

print("\nKNeighborsClassifier:")
neigh = KNeighborsClassifier(n_neighbors=3)
cross_validation(X1n, neigh, folds)

print("\nLogisticRegression:")
logireg = LogisticRegression(C=2.0, fit_intercept=True, penalty='l2', tol=0.001)
cross_validation(X1n, logireg, folds)

print("\nBaggingClassifier:")
bagging = BaggingClassifier(KNeighborsClassifier(n_neighbors=3), max_samples=0.5, max_features=0.5)
cross_validation(X1n, bagging, folds)
# Out:
# SVM:
# Scores      :   [0.93   0.9225 0.9225 0.9225 0.9225]
# Scores Mean :   0.924
# Scores std  :   0.0030000000000000248
#
# KNeighborsClassifier:
# Scores      :   [0.905  0.91   0.9275 0.905  0.9075]
# Scores Mean :   0.9109999999999999
# Scores std  :   0.008455767262643871
#
# LogisticRegression:
# Scores      :   [0.845  0.8325 0.855  0.845  0.82  ]
# Scores Mean :   0.8394999999999999
# Scores std  :   0.012083045973594577
#
# BaggingClassifier:
# Scores      :   [0.5275 0.52   0.695  0.5075 0.7275]
# Scores Mean :   0.5954999999999999
# Scores std  :   0.09528116288123273

# %% [markdown]
# ### 5-Metrics Analysis

# %% [markdown]
# ### Precision Recall and ROC

# %%
#Farem servir els 2 mètodes que fins ara ens han donat millors scores
x_t, x_v, y_t, y_v = train_test_split(X1n, y, train_size=0.8, stratify=y)

#Kneigbors
neigh = KNeighborsClassifier(n_neighbors=3)
neigh.fit(x_t,y_t)
probn = neigh.predict_proba(x_v)
print ("Correct classification Kneighbors:          ", neigh.score(x_v, y_v))
#SVM
svc = svm.SVC(C=10.0, kernel='rbf', gamma=0.9, probability=True)
svc.fit(x_t, y_t)
probsvm = svc.predict_proba(x_v)
print ("Correct classification SVM:                ", svc.score(x_v, y_v))
# Out:
# Correct classification Kneighbors:           0.895
# Correct classification SVM:                 0.915

# %%
def precision_recall_roc(probs):
    n_classes=4
    # Compute Precision-Recall and plot curve
    precision = {}
    recall = {}
    average_precision = {}
    plt.figure()
    for i in range(n_classes):
        precision[i], recall[i], _ = precision_recall_curve(y_v == i, probs[:, i])
        average_precision[i] = average_precision_score(y_v == i, probs[:, i])

        plt.plot(recall[i], precision[i],
        label='Precision-Recall curve class {0} (area = {1:0.2f})'
                               ''.format(i, average_precision[i]))
        plt.xlabel('Recall')
        plt.ylabel('Precision')
        plt.legend(loc="lower left")

    # Compute ROC curve and ROC area for each class
    fpr = {}
    tpr = {}
    roc_auc = {}
    for i in range(n_classes):
        fpr[i], tpr[i], _ = roc_curve(y_v == i, probs[:, i])
        roc_auc[i] = auc(fpr[i], tpr[i])

    # Compute micro-average ROC curve and ROC area
    # Plot ROC curve
    plt.figure()
    for i in range(n_classes):
        plt.plot(fpr[i], tpr[i], label='ROC curve of class {0} (area = {1:0.2f})' ''.format(i, roc_auc[i]))
    plt.legend()

# %% [markdown]
# ### Precision&Recall i ROC per Kneighbors

# %%
precision_recall_roc(probn)

# %% [markdown]
# ### Precision&Recall i ROC per SVM

# %%
precision_recall_roc(probsvm)

# %% [markdown]
# ### Classification Reports

# %%
def class_report(y_true, y_pred):
    target_names = ['class 0', 'class 1', 'class 2', 'class 3']
    print(classification_report(y_true, y_pred, target_names=target_names))

# %%
#Farem servir els 2 mètodes que fins ara ens han donat millors scores
x_t, x_v, y_t, y_v = train_test_split(X1n, y, train_size=0.8, stratify=y)

# %% [markdown]
# ### SVM

# %%
svc = svm.SVC(C=35.0, kernel='rbf', gamma=0.1, probability=True)
svc.fit(x_t, y_t)
print ("Correct classification SVM:                ", svc.score(x_v, y_v))
y_true = y_v
y_pred = neigh.predict(x_v)
class_report(y_true, y_pred)
# Out:
# Correct classification SVM:                 0.9425
#               precision    recall  f1-score   support
#
#      class 0       0.96      0.99      0.98       100
#      class 1       0.94      0.95      0.95       100
#      class 2       0.93      0.91      0.92       100
#      class 3       0.96      0.94      0.95       100
#
#     accuracy                           0.95       400
#    macro avg       0.95      0.95      0.95       400
# weighted avg       0.95      0.95      0.95       400

# %% [markdown]
# ### KNeighbors

# %%
#Kneigbors
neigh = KNeighborsClassifier(n_neighbors=7)
neigh.fit(x_t,y_t)
print ("Correct classification Kneighbors:          ", neigh.score(x_v, y_v))
y_true = y_v
y_pred = neigh.predict(x_v)
class_report(y_true, y_pred)
# Out:
# Correct classification Kneighbors:           0.92
#               precision    recall  f1-score   support
#
#      class 0       0.93      0.96      0.95       100
#      class 1       0.89      0.93      0.91       100
#      class 2       0.92      0.86      0.89       100
#      class 3       0.93      0.93      0.93       100
#
#     accuracy                           0.92       400
#    macro avg       0.92      0.92      0.92       400
# weighted avg       0.92      0.92      0.92       400

# %% [markdown]
# ### 6- Hyperparameter Search

# %% [markdown]
# #### Pel mètode SVM trobarem la millor C i la millor gamma

# %%
folds = 5
maxi = 0
for c in range(1,50):
    svc = svm.SVC(C=c, kernel='rbf', gamma=0.1, probability=True)
    scores = cross_val_score(svc, X1n, y, cv=5)
    m = scores.mean()
    if (m > maxi):
        maxi = m
        c_max = c
print("Millor c:    ", c_max)
print("Score màxim: ", maxi)
# Out:
# Millor c:     35
# Score màxim:  0.9425000000000001

# %%
maxi = 0
l = []
for i in range(10):
    l.append(round(i/10,2)+0.1)
for g in l:
    svc = svm.SVC(C=35.0, kernel='rbf', gamma=g, probability=True)
    scores = cross_val_score(svc, X1n, y, cv=5)
    m = scores.mean()
    if (m > maxi):
        maxi = m
        g_max = g
print("Millor gamma: ", g_max)
print("Score màxim:  ", maxi)
# Out:
# Millor gamma:  0.1
# Score màxim:   0.9425000000000001

# %% [markdown]
# #### Pel KNeighbors trobem la millor la n

# %%
maxi = 0
for n in range(1,50):
    neigh = KNeighborsClassifier(n_neighbors=n)
    scores = cross_val_score(neigh, X1n, y, cv=5)
    m = scores.mean()
    if (m > maxi):
        maxi = m
        n_max = n
print("Millor n:    ", n_max)
print("Score màxim: ", maxi)
# Out:
# Millor n:     7
# Score màxim:  0.9189999999999999

# %% [markdown]
# ### PREDICTION

# %%
cols_corr.remove('price_range')
dataset1_test = dataset_test[cols_corr]
X_test = dataset1_test.values
Xn_test = standarize(X_test)

# %% [markdown]
# ### Predicció del dataset de Test amb SVM

# %%
svc = svm.SVC(C=35.0, kernel='rbf', gamma=0.1, probability=True)
svc.fit(X1n, y)
svc_pred = svc.predict(Xn_test)
unique, counts = np.unique(svc_pred, return_counts=True)
coun = dict(zip(unique, counts))
print(coun)
# Out:
# {0.0: 251, 1.0: 227, 2.0: 266, 3.0: 256}

# %% [markdown]
# ### Predicció del dataset de Test amb KNeighbors

# %%
#Kneigbors
neigh = KNeighborsClassifier(n_neighbors=7)
neigh.fit(X1n, y)
ne_pred = neigh.predict(Xn_test)
unique, counts = np.unique(ne_pred, return_counts=True)
coun2 = dict(zip(unique, counts))
print(coun2)
# Out:
# {0.0: 251, 1.0: 232, 2.0: 255, 3.0: 262}

# %% [markdown]
# ### Pairplot del test amb les prediccions de SVM

# %%
datasetpred=dataset1_test
datasetpred['price_range'] = ne_pred
sns.pairplot(datasetpred, hue='price_range')
